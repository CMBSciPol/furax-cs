# %%
import os

import matplotlib.pyplot as plt
import scienceplots  # noqa: F401
from jax_hpc_profiler import plot_weak_scaling

out_folder = "plots"
os.makedirs(out_folder, exist_ok=True)


# Set the style for the plots
plt.style.use("science")
font_size = 16
plt.rcParams.update(
    {
        "font.size": font_size,
        "axes.labelsize": font_size,
        "xtick.labelsize": font_size,
        "ytick.labelsize": font_size,
        "legend.fontsize": font_size,
        "axes.titlesize": font_size,
        "font.family": "serif",  # or 'Times New Roman' to match LaTeX
        "legend.frameon": True,  # Add boxed legends
    }
)

# %%
csv_file = ["runs/CLUSTERS_FGBUSTER.csv", "runs/CLUSTERS_FURAX.csv"]
label_text = "%f%"

plot_weak_scaling(
    csv_files=csv_file,
    functions=[
        "(This work) Furax",
        "FGBuster Scipy-TNC",
    ],
    figure_size=(7, 5.5),
    precisions=["float64"],
    label_text=label_text,
    xlabel="Number of Patches",
    title=None,
    output="runtime_comparison.png",
    # output=f"{out_folder}/runtime_comparison.pdf",
)
# Out:
# requested GPUS: None available GPUS: {np.int64(1)}
# requested data sizes: None available data sizes: {np.int64(8000), np.int64(4000), np.int64(1000), np.int64(5000), np.int64(9000), np.int64(6000), np.int64(2000), np.int64(10000), np.int64(7000), np.int64(3000)}
# yo
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
