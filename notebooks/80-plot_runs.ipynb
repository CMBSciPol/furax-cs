# %%
import os

import matplotlib.pyplot as plt
import scienceplots  # noqa: F401
from jax_hpc_profiler import plot_by_gpus

out_folder = "plots"
os.makedirs(out_folder, exist_ok=True)


# Set the style for the plots
plt.style.use("science")
font_size = 18
plt.rcParams.update(
    {
        "font.size": font_size,
        "axes.labelsize": font_size,
        "xtick.labelsize": font_size,
        "ytick.labelsize": font_size,
        "legend.fontsize": font_size,
        "axes.titlesize": font_size,
        "font.family": "serif",  # or 'Times New Roman' to match LaTeX
        "legend.frameon": True,  # Add boxed legends
        "text.usetex": True,  # Use LaTeX for text rendering
    }
)
# Out:
# /home/wassim/micromamba/envs/fg/lib/python3.11/site-packages/jaxlib/plugin_support.py:91: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.9.1 is installed, but it is not compatible with the installed jaxlib version 0.9.2, so it will not be used.
#   warnings.warn(

# %%
csv_file = ["runs/CLUSTERS_FGBUSTER.csv", "runs/CLUSTERS_FURAX.csv"]
label_text = "%f%"

plot_by_gpus(
    csv_files=csv_file,
    functions=[
        "Furax-ADABK0 n=64",
        "FGBuster-TNC n=64",
    ],
    figure_size=(8, 6),
    precisions=["float64"],
    label_text=label_text,
    xlabel="Number of Patches",
    plot_columns=["min_time"],
    title=None,
    output="runtime_comparison.pdf",
    use_cube_notation=False,
    # output=f"{out_folder}/runtime_comparison.pdf",
)
# Out:
# requested GPUS: None available GPUS: {np.int64(1)}
#
#         requested data sizes: None
#         available global volumes: {np.int64(4000), np.int64(8000), np.int64(1000), np.int64(5000), np.int64(9000), np.int64(2000), np.int64(6000), np.int64(10000), np.int64(7000), np.int64(3000)}
